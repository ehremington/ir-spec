# %%
import numpy as np

# %%
A = np.array([[1,2],[3,4]])
np.disp(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A[0][1]
# Out:
# 2

# %%
B = np.array([[5,6],[7,8]])

# %%
np.inner(A,B)
# Out:
# array([[17, 23],
#        [39, 53]])
