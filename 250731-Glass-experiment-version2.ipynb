# %%
# %matplotlib widget 

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd     

df = pd.read_excel("glass.xlsx")  # Or .csv with pd.read_csv

# Extract columns into arrays- this will be changed one i get exell file
wave_numbers = df["wave_numbers"].values
n0_array = df["n0"].values
k0_array = df["k0"].values
n0p50_array = df["n0p50"].values
k0p50_array = df["k0p50"].values
n0p55_array = df["n0p55"].values
k0p55_array = df["k0p55"].values
n0p60_array = df["n0p60"].values
k0p60_array = df["k0p60"].values
n0p65_array = df["n0p65"].values
k0p65_array = df["k0p65"].values
n0p70_array = df["n0p70"].values
k0p70_array = df["k0p70"].values
n0p75_array = df["n0p75"].values
k0p75_array = df["k0p75"].values
n0p80_array = df["n0p80"].values
k0p80_array = df["k0p80"].values
n0p85_array = df["n0p85"].values
k0p85_array = df["k0p85"].values
n0p90_array = df["n0p90"].values
k0p90_array = df["k0p90"].values
n0p95_array = df["n0p95"].values
k0p95_array = df["k0p95"].values
n1p00_array = df["n1p00"].values
k1p00_array = df["k1p00"].values
n1p05_array = df["n1p05"].values
k1p05_array = df["k1p05"].values
n1p10_array = df["n1p10"].values
k1p10_array = df["k1p10"].values
n1p15_array = df["n1p15"].values
k1p15_array = df["k1p15"].values
n1p20_array = df["n1p20"].values
k1p20_array = df["k1p20"].values
n1p25_array = df["n1p25"].values
k1p25_array = df["k1p25"].values
n1p30_array = df["n1p30"].values
k1p30_array = df["k1p30"].values
n1p35_array = df["n1p35"].values
k1p35_array = df["k1p35"].values
n1p40_array = df["n1p40"].values
k1p40_array = df["k1p40"].values
n1p45_array = df["n1p45"].values
k1p45_array = df["k1p45"].values
n1p50_array = df["n1p50"].values
k1p50_array = df["k1p50"].values
n1p55_array = df["n1p55"].values
k1p55_array = df["k1p55"].values
n1p60_array = df["n1p60"].values
k1p60_array = df["k1p60"].values
n1p65_array = df["n1p65"].values
k1p65_array = df["k1p65"].values
n1p70_array = df["n1p70"].values
k1p70_array = df["k1p70"].values
n1p75_array = df["n1p75"].values
k1p75_array = df["k1p75"].values
n1p80_array = df["n1p80"].values
k1p80_array = df["k1p80"].values
n1p85_array = df["n1p85"].values
k1p85_array = df["k1p85"].values
n1p90_array = df["n1p90"].values
k1p90_array = df["k1p90"].values
n1p95_array = df["n1p95"].values
k1p95_array = df["k1p95"].values
n2p00_array = df["n2p00"].values
k2p00_array = df["k2p00"].values




def cos(th):
    return np.cos(th*np.pi/180) 

def costht(ni, nt, ki, kt, thi):
    return(np.sqrt(1-((ni+1j*ki)/(nt+1j*kt)*sin(thi))**2)) 

def arcsin(ratio):
    return np.arcsin(ratio)*180/np.pi 

def sin(th):
    return np.sin(th*np.pi/180) 

# 3 Returns transmitted angle from incident angle
def snells(ni, nt, ki, kt, thi):
    return(arcsin((ni+1j*ki)/(nt+1j*kt)*sin(thi)))   


def RefractedAnglePlot(snells, wave_numbers, n0_array, k0_array, n0p50_array, k0p50_array, n0p55_array, k0p55_array, n0p60_array, k0p60_array, 
n0p65_array, k0p65_array, n0p70_array, k0p70_array, n0p75_array, k0p75_array, n0p80_array, k0p80_array, n0p85_array, k0p85_array, n0p90_array, 
k0p90_array, n0p95_array, k0p95_array, n1p00_array, k1p00_array, n1p05_array, k1p05_array, n1p10_array, k1p10_array, n1p15_array, k1p15_array, 
n1p20_array, k1p20_array, n1p25_array, k1p25_array, n1p30_array, k1p30_array, n1p35_array, k1p35_array, n1p40_array, k1p40_array, n1p45_array, 
k1p45_array, n1p50_array, k1p50_array, n1p55_array, k1p55_array, n1p60_array, k1p60_array, n1p65_array, k1p65_array, n1p70_array, k1p70_array, n1p75_array, 
k1p75_array, n1p80_array, k1p80_array, n1p85_array, k1p85_array, n1p90_array, k1p90_array, n1p95_array, k1p95_array, n2p00_array, k2p00_array):
    fig0 = plt.figure(figsize=(8,5))
    ax0 = fig0.add_subplot(111)
    th0 = np.linspace(0.1,89.9,10000)
    line01, = ax0.plot([], [], 'b-')   # blue solid
    line02, = ax0.plot([], [], 'r-')   # red solid
    line03, = ax0.plot([], [], 'g-')   # green solid
    line04, = ax0.plot([], [], 'm-')   # magenta solid
    line05, = ax0.plot([], [], 'c-')   # cyan solid
    line06, = ax0.plot([], [], 'y-')   # yellow solid
    line07, = ax0.plot([], [], 'k-')   # black solid
    line08, = ax0.plot([], [], 'b--')  # blue dashed
    line09, = ax0.plot([], [], 'r--')  # red dashed
    line10, = ax0.plot([], [], 'g--')  # green dashed
    line11, = ax0.plot([], [], 'm--')  # magenta dashed
    line12, = ax0.plot([], [], 'c--')  # cyan dashed
    line13, = ax0.plot([], [], 'y--')  # yellow dashed
    line14, = ax0.plot([], [], 'k--')  # black dashed
    line15, = ax0.plot([], [], 'b-.')  # blue dash-dot
    line16, = ax0.plot([], [], 'r-.')  # red dash-dot
    line17, = ax0.plot([], [], 'g-.')  # green dash-dot
    line18, = ax0.plot([], [], 'm-.')  # magenta dash-dot
    line19, = ax0.plot([], [], 'c-.')  # cyan dash-dot
    line20, = ax0.plot([], [], 'y-.')  # yellow dash-dot
    line21, = ax0.plot([], [], 'k-.')  # black dash-dot
    line22, = ax0.plot([], [], 'b:')   # blue dotted
    line23, = ax0.plot([], [], 'r:')   # red dotted
    line24, = ax0.plot([], [], 'g:')   # green dotted
    line25, = ax0.plot([], [], 'm:')   # magenta dotted
    line26, = ax0.plot([], [], 'c:')   # cyan dotted
    line27, = ax0.plot([], [], 'y:')   # yellow dotted
    line28, = ax0.plot([], [], 'k:')   # black dotted
    line29, = ax0.plot([], [], 'darkorange')  # orange solid
    line30, = ax0.plot([], [], 'lime')        # lime solid
    line31, = ax0.plot([], [], 'orchid')      # orchid solid
    ax0.set_xlim((0,90))
    ax0.set_ylim((0,90))
    ax0.axhline(0, linewidth=0.75, color='k')
    # ax0.axvline(0, color='k')
    ax0.set_xlabel(r'$\theta_i$')
    ax0.set_ylabel(r'$\theta_R$')
    #ax0.legend([r'rperptotal'],)
    def plot(I=0):
        wn = wave_numbers[I] 
        n0 = n0_array[I] 
        k0 = k0_array[I]
        n0p50 = n0p50_array[I]
        k0p50 = k0p50_array[I]
        n0p55 = n0p55_array[I]
        k0p55 = k0p55_array[I]
        n0p60 = n0p60_array[I]
        k0p60 = k0p60_array[I]
        n0p65 = n0p65_array[I]
        k0p65 = k0p65_array[I]
        n0p70 = n0p70_array[I]
        k0p70 = k0p70_array[I]
        n0p75 = n0p75_array[I]
        k0p75 = k0p75_array[I]
        n0p80 = n0p80_array[I]
        k0p80 = k0p80_array[I]
        n0p85 = n0p85_array[I]
        k0p85 = k0p85_array[I]
        n0p90 = n0p90_array[I]
        k0p90 = k0p90_array[I]
        n0p95 = n0p95_array[I]
        k0p95 = k0p95_array[I]
        n1p00 = n1p00_array[I]
        k1p00 = k1p00_array[I]
        n1p05 = n1p05_array[I]
        k1p05 = k1p05_array[I]
        n1p10 = n1p10_array[I]
        k1p10 = k1p10_array[I]
        n1p15 = n1p15_array[I]
        k1p15 = k1p15_array[I]
        n1p20 = n1p20_array[I]
        k1p20 = k1p20_array[I]
        n1p25 = n1p25_array[I]
        k1p25 = k1p25_array[I]
        n1p30 = n1p30_array[I]
        k1p30 = k1p30_array[I]
        n1p35 = n1p35_array[I]
        k1p35 = k1p35_array[I]
        n1p40 = n1p40_array[I]
        k1p40 = k1p40_array[I]
        n1p45 = n1p45_array[I]
        k1p45 = k1p45_array[I]
        n1p50 = n1p50_array[I]
        k1p50 = k1p50_array[I]
        n1p55 = n1p55_array[I]
        k1p55 = k1p55_array[I]
        n1p60 = n1p60_array[I]
        k1p60 = k1p60_array[I]
        n1p65 = n1p65_array[I]
        k1p65 = k1p65_array[I]
        n1p70 = n1p70_array[I]
        k1p70 = k1p70_array[I]
        n1p75 = n1p75_array[I]
        k1p75 = k1p75_array[I]
        n1p80 = n1p80_array[I]
        k1p80 = k1p80_array[I]
        n1p85 = n1p85_array[I]
        k1p85 = k1p85_array[I]
        n1p90 = n1p90_array[I]
        k1p90 = k1p90_array[I]
        n1p95 = n1p95_array[I]
        k1p95 = k1p95_array[I]
        n2p00 = n2p00_array[I]
        k2p00 = k2p00_array[I]
        
        output1 = snells(n0, n0p50, k0, k0p50, th0)
        line01.set_data(th0, output1)
        output2 = snells(n0, n0p55, k0, k0p55, th0)
        line02.set_data(th0, output2)
        output3 = snells(n0, n0p60, k0, k0p60, th0)
        line03.set_data(th0, output3)
        output4 = snells(n0, n0p65, k0, k0p65, th0)
        line04.set_data(th0, output4)
        output5 = snells(n0, n0p70, k0, k0p70, th0)
        line05.set_data(th0, output5)
        output6 = snells(n0, n0p75, k0, k0p75, th0)
        line06.set_data(th0, output6)
        output7 = snells(n0, n0p80, k0, k0p80, th0)
        line07.set_data(th0, output7)
        output8 = snells(n0, n0p85, k0, k0p85, th0)
        line08.set_data(th0, output8)
        output9 = snells(n0, n0p90, k0, k0p90, th0)
        line09.set_data(th0, output9)
        output10 = snells(n0, n0p95, k0, k0p95, th0)
        line10.set_data(th0, output10)
        output11 = snells(n0, n1p00, k0, k1p00, th0)
        line11.set_data(th0, output11)
        output12 = snells(n0, n1p05, k0, k1p05, th0)
        line12.set_data(th0, output12)
        output13 = snells(n0, n1p10, k0, k1p10, th0)
        line13.set_data(th0, output13)
        output14 = snells(n0, n1p15, k0, k1p15, th0)
        line14.set_data(th0, output14)
        output15 = snells(n0, n1p20, k0, k1p20, th0)
        line15.set_data(th0, output15)
        output16 = snells(n0, n1p25, k0, k1p25, th0)
        line16.set_data(th0, output16)
        output17 = snells(n0, n1p30, k0, k1p30, th0)
        line17.set_data(th0, output17)
        output18 = snells(n0, n1p35, k0, k1p35, th0)
        line18.set_data(th0, output18)
        output19 = snells(n0, n1p40, k0, k1p40, th0)
        line19.set_data(th0, output19)
        output20 = snells(n0, n1p45, k0, k1p45, th0)
        line20.set_data(th0, output20)
        output21 = snells(n0, n1p50, k0, k1p50, th0)
        line21.set_data(th0, output21)
        output22 = snells(n0, n1p55, k0, k1p55, th0)
        line22.set_data(th0, output22)
        output23 = snells(n0, n1p60, k0, k1p60, th0)
        line23.set_data(th0, output23)
        output24 = snells(n0, n1p65, k0, k1p65, th0)
        line24.set_data(th0, output24)
        output25 = snells(n0, n1p70, k0, k1p70, th0)
        line25.set_data(th0, output25)
        output26 = snells(n0, n1p75, k0, k1p75, th0)
        line26.set_data(th0, output26)
        output27 = snells(n0, n1p80, k0, k1p80, th0)
        line27.set_data(th0, output27)
        output28 = snells(n0, n1p85, k0, k1p85, th0)
        line28.set_data(th0, output28)
        output29 = snells(n0, n1p90, k0, k1p90, th0)
        line29.set_data(th0, output29)
        output30 = snells(n0, n1p95, k0, k1p95, th0)
        line30.set_data(th0, output30)
        output31 = snells(n0, n2p00, k0, k2p00, th0)
        line31.set_data(th0, output31)
        plt.draw() 
        print(f"Wavenumber at index {I}: {wn}")
    interact(plot, I=(0, len(n0_array)-1)) 

RefractedAnglePlot(snells, wave_numbers, n0_array, k0_array, n0p50_array, k0p50_array, n0p55_array, k0p55_array, n0p60_array, k0p60_array, 
n0p65_array, k0p65_array, n0p70_array, k0p70_array, n0p75_array, k0p75_array, n0p80_array, k0p80_array, n0p85_array, k0p85_array, n0p90_array, 
k0p90_array, n0p95_array, k0p95_array, n1p00_array, k1p00_array, n1p05_array, k1p05_array, n1p10_array, k1p10_array, n1p15_array, k1p15_array, 
n1p20_array, k1p20_array, n1p25_array, k1p25_array, n1p30_array, k1p30_array, n1p35_array, k1p35_array, n1p40_array, k1p40_array, n1p45_array, 
k1p45_array, n1p50_array, k1p50_array, n1p55_array, k1p55_array, n1p60_array, k1p60_array, n1p65_array, k1p65_array, n1p70_array, k1p70_array, n1p75_array, 
k1p75_array, n1p80_array, k1p80_array, n1p85_array, k1p85_array, n1p90_array, k1p90_array, n1p95_array, k1p95_array, n2p00_array, k2p00_array)
# Out:
# interactive(children=(IntSlider(value=0, description='I', max=800), Output()), _dom_classes=('widget-interact'…
# /home/jupyter-ehreming/.local/lib/python3.12/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
th0 = np.linspace(0.1, 89.9, 10000)

data = {"theta_i_degrees": th0}
index_sets = [
    ("n0", "n0p50", "k0", "k0p50"),
    ("n0", "n0p55", "k0", "k0p55"),
    ("n0", "n0p60", "k0", "k0p60"),
    ("n0", "n0p65", "k0", "k0p65"),
    ("n0", "n0p70", "k0", "k0p70"),
    ("n0", "n0p75", "k0", "k0p75"),
    ("n0", "n0p80", "k0", "k0p80"),
    ("n0", "n0p85", "k0", "k0p85"),
    ("n0", "n0p90", "k0", "k0p90"),
    ("n0", "n0p95", "k0", "k0p95"),
    ("n0", "n1p00", "k0", "k1p00"),
    ("n0", "n1p05", "k0", "k1p05"),
    ("n0", "n1p10", "k0", "k1p10"),
    ("n0", "n1p15", "k0", "k1p15"),
    ("n0", "n1p20", "k0", "k1p20"),
    ("n0", "n1p25", "k0", "k1p25"),
    ("n0", "n1p30", "k0", "k1p30"),
    ("n0", "n1p35", "k0", "k1p35"),
    ("n0", "n1p40", "k0", "k1p40"),
    ("n0", "n1p45", "k0", "k1p45"),
    ("n0", "n1p50", "k0", "k1p50"),
    ("n0", "n1p55", "k0", "k1p55"),
    ("n0", "n1p60", "k0", "k1p60"),
    ("n0", "n1p65", "k0", "k1p65"),
    ("n0", "n1p70", "k0", "k1p70"),
    ("n0", "n1p75", "k0", "k1p75"),
    ("n0", "n1p80", "k0", "k1p80"),
    ("n0", "n1p85", "k0", "k1p85"),
    ("n0", "n1p90", "k0", "k1p90"),
    ("n0", "n1p95", "k0", "k1p95"),
    ("n0", "n2p00", "k0", "k2p00"),
]
I = 382
for (ni_label, nt_label, ki_label, kt_label) in index_sets:
    ni = df[ni_label].iloc[I]     # pick a specific row index I or loop over rows
    ki = df[ki_label].iloc[I]
    nt = df[nt_label].iloc[I]
    kt = df[kt_label].iloc[I]
    col_name = f"{ni_label}_to_{nt_label}"
    data[col_name] = np.real (snells(ni, nt, ki, kt, th0))

# Build DataFrame
angle_df = pd.DataFrame(data)

# Export to CSV
angle_df.to_csv("snells_transmitted_angles.csv", index=False)

print("CSV file 'snells_transmitted_angles.csv' created successfully.")
# Out:
# CSV file 'snells_transmitted_angles.csv' created successfully.
