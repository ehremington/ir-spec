# %% [markdown]
# # joe's talk notes
#
#
# what we really care about is the total field travelling leftward in n0 and the total travelling rightward through n2.
#
# | n_0 | n_1 | n_2 |
# |---|---|---|
# | E_0l | E_1l |  E_2l |
#
#
# $$\begin{bmatrix}
# E_{0r} \\
# E_{0l}
# \end{bmatrix} =
# \begin
# $$
#
# $$D = \frac{1}{t{01}} \begin{bmatrix}
# 1 & r_{01} \\
# r_{01} & 1
# \end{bmatrix}
# $$
#
# $$P = \begin{bmatrix}
# e^{+ik1d \cos{\theta_1} & 0 \\
# 0 & 1
# \end{bmatrix}
# $$
